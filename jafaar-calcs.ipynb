# %% [markdown]
# ### Analysis of Jafaar's scratcher wins in ~2017
# 549 wins of $1000.
#
# Find minimum spend across all scratcher games.

# %%
import csv
import math
import numpy as np
import scipy as sp
from scipy.stats import binom
from scipy.special import betainc
from scipy.optimize import minimize

def binTail(p, n, t): # upper tail probability for a vector of Binomial(n,p) random variables
    return betainc(n, t - n + 1, p)

import pandas as pd
fn = './jafaar-scratchers.csv'  # games and odds

wins = 549
CHANCE_THRESHOLD =  10**(-7) # one in ten million threshold
MAX_PLAYERS = 6859819  # MAX_PLAYERS of MA in 2017 per census
eps = CHANCE_THRESHOLD/MAX_PLAYERS
TOT_REVENUE = 3517783 # Scratcher revenue in MA, 2017

# %%
odds = pd.read_csv(fn)
odds['per_dollar'] = odds['Consolidated odds to win $1,000']/odds['$ cost to play']
oddsBy = odds.groupby('$ cost to play')

# %%
# find max for each ticket cost

print(oddsBy['Consolidated odds to win $1,000'].aggregate('max'))
print(oddsBy['Consolidated odds to win $1,000'].aggregate(np.argmax))
inx = oddsBy['Consolidated odds to win $1,000'].aggregate(np.argmax).values
print(inx)
# Out:
# $ cost to play
# 1     0.000030
# 2     0.000069
# 5     0.000340
# 10    0.000479
# Name: Consolidated odds to win $1,000, dtype: float64
# $ cost to play
# 1      4.0
# 2     20.0
# 5     53.0
# 10    76.0
# Name: Consolidated odds to win $1,000, dtype: float64
# [  4.  20.  53.  76.]
# /anaconda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: 'argmax' is deprecated. Use 'idxmax' instead. The behavior of 'argmax' will be corrected to return the positional maximum in the future. Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)

# %%
odds
# Out:
#                     Instant ticket game  Consolidated odds to win $1,000  \
# 0            $10,000 Holiday Bonus 2015                         0.000010
# 1            $10,000 Holiday Bonus 2017                         0.000014
# 2                     10X The Cash 2016                         0.000010
# 3                    9's in a Line 2017                         0.000010
# 4             $500 a Week For Life 2014                         0.000030
# 5                       Double 8's 2016                         0.000010
# 6                    Double Payday 2018                         0.000010
# 7                     Make My Day™ 2017                         0.000010
# 8                     Wild Doubler 2015                         0.000010
# 9                   $50,000 Bingo Boxes                         0.000028
# 10                     $100 Frenzy 2014                         0.000029
# 11             $100,000 Bonus Cash 2017                         0.000056
# 12           $100,000 Double Match 2016                         0.000063
# 13                $100,000 Pay Day 2017                         0.000056
# 14                      fast $100s 2018                         0.000063
# 15             $100,000 Taxes Paid 2016                         0.000056
# 16        $100,000 Triple Diamonds 2016                         0.000056
# 17           $1000 a Week for Life 2014                         0.000056
# 18                   4 Leaf Clover 2017                         0.000063
# 19                          24K Madness                         0.000063
# 20              Bingo Star Tripler 2013                         0.000069
# 21                   Boston Bruins 2014                         0.000028
# 22                  Boston Red Sox 2014                         0.000014
# 23                  Break the Bank 2015                         0.000063
# 24                 Easy as...1,2,3 2018                         0.000049
# 25                      Fast $100s 2018                         0.000005
# 26                       Hit $200! 2016                         0.000028
# 27                   Lucky Tripler 2018                         0.000055
# 28                   Magic 8 Ball™ 2015                         0.000063
# 29               Money Money Money 2015                         0.000063
# ..                                  ...                              ...
# 51         $1,000,000 Players Club 2015                         0.000174
# 52                  Corvette® Cash 2017                         0.000056
# 53                     Creepy Cash 2017                         0.000340
# 54                     Extra Plays 2017                         0.000174
# 55                        Hit $500 2016                         0.000139
# 56                     Jumbo Bucks 2015                         0.000194
# 57                  Make My Month™ 2017                         0.000194
# 58                    Monster Cash 2015                         0.000340
# 59            Red Hot and Wild 7's 2015                         0.000181
# 60                  Road to Riches 2016                         0.000208
# 61       Silver, Gold, Platinum 8s 2014                         0.000333
# 62                     Spooky Cash 2016                         0.000340
# 63           Ultimate Garden Party 2015                         0.000112
# 64                      Win It All 2016                         0.000174
# 65  WPT®$1,000,000 Hold 'em Poker® 2017                         0.000167
# 66              $2,000,000 50X Cashword                         0.000250
# 67        $2,500,000 Holiday Gifts 2014                         0.000428
# 68        $2,500,000 Holiday Bonus 2017                         0.000403
# 69        $2,500,000 Holiday Magic 2016                         0.000403
# 70        $200,000 A Year For Life 2017                         0.000472
# 71           $4,000,000 Bonus Cash 2017                         0.000444
# 72         $4,000,000 Gold Bullion 2014                         0.000444
# 73      $4,000,000 Instant Jackpot 2017                         0.000444
# 74               $4,000,000 Payout 2015                         0.000444
# 75              $4,000,000 Winfall 2015                         0.000444
# 76                            100X 2017                         0.000479
# 77                   100X The Cash 2016                         0.000444
# 78                     Hit $1,000! 2016                         0.000479
# 79                Monopoly Jackpot 2016                         0.000444
# 80           Willy Wonka Golden Ticket™                         0.000444
#
#     $ cost to play  per_dollar
# 0                1    0.000010
# 1                1    0.000014
# 2                1    0.000010
# 3                1    0.000010
# 4                1    0.000030
# 5                1    0.000010
# 6                1    0.000010
# 7                1    0.000010
# 8                1    0.000010
# 9                2    0.000014
# 10               2    0.000014
# 11               2    0.000028
# 12               2    0.000031
# 13               2    0.000028
# 14               2    0.000031
# 15               2    0.000028
# 16               2    0.000028
# 17               2    0.000028
# 18               2    0.000031
# 19               2    0.000031
# 20               2    0.000035
# 21               2    0.000014
# 22               2    0.000007
# 23               2    0.000031
# 24               2    0.000024
# 25               2    0.000002
# 26               2    0.000014
# 27               2    0.000027
# 28               2    0.000031
# 29               2    0.000031
# ..             ...         ...
# 51               5    0.000035
# 52               5    0.000011
# 53               5    0.000068
# 54               5    0.000035
# 55               5    0.000028
# 56               5    0.000039
# 57               5    0.000039
# 58               5    0.000068
# 59               5    0.000036
# 60               5    0.000042
# 61               5    0.000067
# 62               5    0.000068
# 63               5    0.000022
# 64               5    0.000035
# 65               5    0.000033
# 66              10    0.000025
# 67              10    0.000043
# 68              10    0.000040
# 69              10    0.000040
# 70              10    0.000047
# 71              10    0.000044
# 72              10    0.000044
# 73              10    0.000044
# 74              10    0.000044
# 75              10    0.000044
# 76              10    0.000048
# 77              10    0.000044
# 78              10    0.000048
# 79              10    0.000044
# 80              10    0.000044
#
# [81 rows x 4 columns]

# %%
game = odds.iloc[inx]
game
# Out:
#           Instant ticket game  Consolidated odds to win $1,000  \
# 4   $500 a Week For Life 2014                         0.000030
# 20    Bingo Star Tripler 2013                         0.000069
# 53           Creepy Cash 2017                         0.000340
# 76                  100X 2017                         0.000479
#
#     $ cost to play  per_dollar
# 4                1    0.000030
# 20               2    0.000035
# 53               5    0.000068
# 76              10    0.000048

# %%
def findn(p, k, eps, maxiter = 10**4):
    """
    Find the sample size n for a binomial such that the chance of k or more successes in
    n Bernoulli(p) trials is at least eps
    """
    nmax = math.ceil(k/p)
    assert binTail(p, k, nmax) > eps
    while binTail(p, k, nmax) > eps:
        nmax = nmax/2
    nmax = nmax/2
    nmin = k
    assert binTail(p, k, nmin) < eps
    while binTail(p, k, nmin) < eps:
        nmin = 2*nmin
    nmin = 2*nmin
    f = lambda x: binTail(p, k, x)-eps
    return math.ceil(sp.optimize.brentq(f, nmin, nmax, maxiter=maxiter))

# %%
minspend = 10**9
minmult = 10**10

for i in range(len(game['Instant ticket game'])):
    r = game.iloc[i]
    p = r['Consolidated odds to win $1,000']
    n = findn(p,wins,eps)
    c = r['$ cost to play']*n
    if c < minspend:
        minspend = c 
        minmult = MAX_PLAYERS*c/TOT_REVENUE    
    print('\n\n', r)
    print(p, wins, n, c, MAX_PLAYERS*c/TOT_REVENUE)
    
print('\n\n', minspend, minmult, minmult*TOT_REVENUE)
# Out:
#  Instant ticket game                $500 a Week For Life 2014
# Consolidated odds to win $1,000                  2.97619e-05
# $ cost to play                                             1
# per_dollar                                       2.97619e-05
# Name: 4, dtype: object
# 2.97619e-05 549 13081486 13081486 25509426.3094
#
#
#  Instant ticket game                Bingo Star Tripler 2013
# Consolidated odds to win $1,000                6.94444e-05
# $ cost to play                                           2
# per_dollar                                     3.47222e-05
# Name: 20, dtype: object
# 6.94444e-05 549 5606399 11212798 21865409.1977
#
#
#  Instant ticket game                Creepy Cash 2017
# Consolidated odds to win $1,000         0.000340368
# $ cost to play                                    5
# per_dollar                              6.80736e-05
# Name: 53, dtype: object
# 0.000340368 549 1143923 5719615 11153480.3738
#
#
#  Instant ticket game                  100X 2017
# Consolidated odds to win $1,000    0.000479386
# $ cost to play                              10
# per_dollar                         4.79386e-05
# Name: 76, dtype: object
# 0.000479386 549 812218 8122180 15838579.209
# 5719615 11153480.3738 3.92355236497e+13

# %%
f = lambda x: binTail(p, k, x)-eps
k = wins
p = 0.000340368
print(f(5719615/5), binTail(p, wins, 5719615/5), eps)
# Out:
# 1.72820942153e-18 1.45793723134e-14 1.457764410402082e-14

# %%
TOT_REVENUE/MAX_PLAYERS # sanity check
# Out:
# 0.5128098860917467

# %%
TOT_REVENUE*11*10**6/(3.9*10**13) # double check
# Out:
# 0.9921952051282051
